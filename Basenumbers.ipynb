# %% [markdown]
# # Convert 3 digit base 7 number to base 10

# %%
x = 154

# %%
d0 = x % 10
print(d0)
# Out:
# 4

# %%
x = x // 10
x
# Out:
# 15

# %%
d1 = x % 10
print(d1)
# Out:
# 5

# %%
x = x // 10
x
# Out:
# 1

# %%
d2 = x % 10
print(d2)
# Out:
# 1

# %%
print(d0, d1, d2)
# Out:
# 4 5 1

# %%
d0, d1, d2
# Out:
# (4, 5, 1)

# %%
d0 + 7*d1 + 7*7*d2
# Out:
# 88

# %% [markdown]
# # Convert 4 digit base 8 number to base 10 number

# %%
x = 2756

# %%
d0 = x % 10
print(d0)
# Out:
# 6

# %%
x = x // 10
x
# Out:
# 275

# %%
d1 = x % 10
print(d1)
# Out:
# 5

# %%
x = x // 10
x
# Out:
# 27

# %%
d2 = x % 10
print(d2)
# Out:
# 7

# %%
x = x // 10
x
# Out:
# 2

# %%
d3 = x % 10
print(d3)
# Out:
# 2

# %%
print(d0, d1, d2, d3)
# Out:
# 6 5 7 2

# %%
d0, d1, d2, d3
# Out:
# (6, 5, 7, 2)

# %%
d0 + 8*d1 + 8*8*d2 + 8*8*8*d3
# Out:
# 1518

# %%
#Another way of solving this problem

# %%
x = 2756
multiplier = 1
result = 0
mybase = 8

# %%
print("Number:" , x)
d = x % 10
print("Last Digit:" , d)
print("Multiplier:" , multiplier)
result += d*multiplier
print("Result:" , result)
# Out:
# Number: 2756
# Last Digit: 6
# Multiplier: 1
# Result: 6

# %%
x= x // 10
x
multiplier *= mybase
print("New Number:" , x)
print("New Multiplier:" , multiplier)
# Out:
# New Number: 275
# New Multiplier: 8

# %%
print("Number:" , x)
d = x % 10
print("Last Digit:" , d)
print("Multiplier:" , multiplier)
result += d*multiplier
print("Result:" , result)
# Out:
# Number: 275
# Last Digit: 5
# Multiplier: 8
# Result: 46

# %%
x = x // 10
x
multiplier *= mybase
print("New Number:" , x)
print("New Multiplier:" , multiplier)
# Out:
# New Number: 27
# New Multiplier: 64

# %%
print("Number:" , x)
d = x % 10
print("Last digit:" , d)
print("Multiplier:" , multiplier)
result += d*multiplier
print("Result:" , result)
# Out:
# Number: 27
# Last digit: 7
# Multiplier: 64
# Result: 494

# %%
x = x // 10
x
multiplier *= mybase
print("New Number:" , x)
print("New Multiplier:" , multiplier)
# Out:
# New Number: 2
# New Multiplier: 512

# %%
print("Number:" , x)
d = x % 10
print("Last Digit:" , d)
print("Multiplier:" , multiplier)
result += d*multiplier
print("Result:" , result)
# Out:
# Number: 2
# Last Digit: 2
# Multiplier: 512
# Result: 1518

# %%
x = x // 10
x
multiplier *= mybase
print("New Number:" , x)
print("New Multiplier:" , multiplier)
# Out:
# New Number: 0
# New Multiplier: 4096

# %%
print("Result:" , result)
# Out:
# Result: 1518

# %%
#Another way of solving this problem

# %% [markdown]
# # Functions

# %%
x = 2756
result = 0
multiplier = 1
mybase = 8

# %%
def extract_last_digit():
    global x
    global result
    global multiplier
    print("Number:" , x)
    d = x % 10
    print("Last Digit:" , d)
    print("Multiplier:" , multiplier)
    result += d*multiplier
    print("Result:" , result)
    x = x // 10
    multiplier *= mybase
    print("New Number:" , x)
    print("New Multiplier:" , multiplier)

# %%
extract_last_digit()
# Out:
# Number: 2756
# Last Digit: 6
# Multiplier: 1
# Result: 6
# New Number: 275
# New Multiplier: 8

# %%
extract_last_digit()
# Out:
# Number: 275
# Last Digit: 5
# Multiplier: 8
# Result: 46
# New Number: 27
# New Multiplier: 64

# %%
extract_last_digit()
# Out:
# Number: 27
# Last Digit: 7
# Multiplier: 64
# Result: 494
# New Number: 2
# New Multiplier: 512

# %%
extract_last_digit()
# Out:
# Number: 2
# Last Digit: 2
# Multiplier: 512
# Result: 1518
# New Number: 0
# New Multiplier: 4096

# %%
#Another way of solving this problem

# %% [markdown]
# # Recursion

# %%
x = 2756
result = 0
multiplier = 1
mybase = 8

# %%
def extract_lastdigit():
    global x
    global result
    global multiplier
    print("-"*10)
    print("Number:" , x)
    
    d = x % 10
    print("Last Digit:" , d)
    print("Multiplier:" , multiplier)
    result += d*multiplier
    print("Result:" , result)
    x = x // 10
    multiplier *= mybase
    print("New Number:" , x)
    print("New Multiplier:" , multiplier)
    
    if x == 0:
        print("The number is zero. Stop!")
    else:
        extract_lastdigit()

# %%
extract_lastdigit()
# Out:
# ----------
# Number: 2756
# Last Digit: 6
# Multiplier: 1
# Result: 6
# New Number: 275
# New Multiplier: 8
# ----------
# Number: 275
# Last Digit: 5
# Multiplier: 8
# Result: 46
# New Number: 27
# New Multiplier: 64
# ----------
# Number: 27
# Last Digit: 7
# Multiplier: 64
# Result: 494
# New Number: 2
# New Multiplier: 512
# ----------
# Number: 2
# Last Digit: 2
# Multiplier: 512
# Result: 1518
# New Number: 0
# New Multiplier: 4096
# The number is zero. Stop!

# %%
#Another way of solving this problem

# %% [markdown]
# # If-Else If Condition

# %%
x = -2756
result = 0
multiplier = 1
mybase = 8

# %%
def extract_lastdigit():
    global x
    global result
    global multiplier
    print("-"*10)
    print("Number:" , x)

    d = x % 10
    print("Last Digit:" , d)
    print("Multiplier:" , multiplier)
    result += d*multiplier
    print("Result:" , result)
    x = x // 10
    multiplier *= mybase
    print("New Number:" , x)
    print("Result:" , result)

    if x == 0:
        print("The number is zero. Stop!")
        print("Final Result:" , result)
    
    elif x < 0:
        print("Mission impossible.")
        
    else:
        extract_lastdigit()

# %%
extract_lastdigit()
# Out:
# ----------
# Number: -2756
# Last Digit: 4
# Multiplier: 1
# Result: 4
# New Number: -276
# Result: 4
# Mission impossible.

# %%
#Another way of solving this problem

# %% [markdown]
# # While loop

# %%
x = 2756
multiplier = 1
result = 0
mybase = 8

# %%
def extract_lastdigit():
    global x
    global result
    global multiplier
    print("-"*10)
    print("Number:" , x)
    
    d = x % 10
    print("Last digit:" , d)
    print("Multiplier:" , multiplier)
    result += d * multiplier
    print("Result:" , result)
    x = x // 10
    print("New Number:" , x)
    print("New Multiplier:" , multiplier)

while x > 0:
    extract_lastdigit()
    print("X in loop:" , x)
# Out:
# ----------
# Number: 2756
# Last digit: 6
# Multiplier: 1
# Result: 6
# New Number: 275
# New Multiplier: 1
# X in loop: 275
# ----------
# Number: 275
# Last digit: 5
# Multiplier: 1
# Result: 11
# New Number: 27
# New Multiplier: 1
# X in loop: 27
# ----------
# Number: 27
# Last digit: 7
# Multiplier: 1
# Result: 18
# New Number: 2
# New Multiplier: 1
# X in loop: 2
# ----------
# Number: 2
# Last digit: 2
# Multiplier: 1
# Result: 20
# New Number: 0
# New Multiplier: 1
# X in loop: 0
